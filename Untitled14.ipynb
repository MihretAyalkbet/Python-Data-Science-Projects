# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c6be9b3-0466-41ad-8f70-cdeb948e49a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c6be9b3-0466-41ad-8f70-cdeb948e49a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Provider_Info.csv")

# %%
df.columns
# Out:
# Index(['index', 'Federal Provider Number', 'Provider Name', 'Provider Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Provider Phone Number', 'Provider SSA County Code',
#        'Provider County Name', 'Ownership Type', 'Number of Certified Beds',
#        'Number of Residents in Certified Beds', 'Provider Type',
#        'Provider Resides in Hospital', 'Legal Business Name',
#        'Date First Approved to Provide Medicare and Medicaid services',
#        'Continuing Care Retirement Community', 'Special Focus Facility',
#        'Most Recent Health Inspection More Than 2 Years Ago',
#        'Provider Changed Ownership in Last 12 Months',
#        'With a Resident and Family Council',
#        'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
#        'Overall Rating Footnote', 'Health Inspection Rating',
#        'Health Inspection Rating Footnote', 'QM Rating', 'QM Rating Footnote',
# ...

# %%
df.columns.tolist()
# Out:
# ['index',
#  'Federal Provider Number',
#  'Provider Name',
#  'Provider Address',
#  'Provider City',
#  'Provider State',
#  'Provider Zip Code',
#  'Provider Phone Number',
#  'Provider SSA County Code',
#  'Provider County Name',
#  'Ownership Type',
#  'Number of Certified Beds',
#  'Number of Residents in Certified Beds',
#  'Provider Type',
#  'Provider Resides in Hospital',
#  'Legal Business Name',
#  'Date First Approved to Provide Medicare and Medicaid services',
#  'Continuing Care Retirement Community',
#  'Special Focus Facility',
#  'Most Recent Health Inspection More Than 2 Years Ago',
#  'Provider Changed Ownership in Last 12 Months',
#  'With a Resident and Family Council',
#  'Automatic Sprinkler Systems in All Required Areas',
#  'Overall Rating',
#  'Overall Rating Footnote',
#  'Health Inspection Rating',
#  'Health Inspection Rating Footnote',
#  'QM Rating',
#  'QM Rating Footnote',
#  'Staffing Rating',
#  'Staffing Rating Footnote',
#  'RN Staffing Rating',
# ...

# %%
important_cols = [
    "Provider Name",
    "Provider Address",
    "Provider City",
    "Provider State",
    "Provider Zip Code",
    "Provider County Name",
    "Ownership Type",
    "Overall Rating",
    "Health Inspection Rating",
    "QM Rating",
    "Staffing Rating",
    "RN Staffing Rating",
    "Number of Certified Beds",
    "Location"
]

df_clean = df[important_cols]
df_clean.to_csv("provider_info_cleaned.csv", index=False)

print(df_clean.head())
print(df_clean.shape)
# Out:
#                                      Provider Name  \
# 0  MERRY WOOD LODGE CARE AND REHABILITATION CENTER
# 1                                RIVER CITY CENTER
# 2  MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER
# 3                   SHADESCREST HEALTH CARE CENTER
# 4                   WASHINGTON COUNTY NURSING HOME
#
#                    Provider Address Provider City Provider State  \
# 0                       P O BOX 130        ELMORE             AL
# 1  1350 FOURTEENTH AVENUE SOUTHEAST       DECATUR             AL
# 2                 603 WRIGHT STREET      TUSKEGEE             AL
# 3              331 WEST 25TH STREET        JASPER             AL
# 4          14600 ST STEPHENS AVENUE        CHATOM             AL
#
#    Provider Zip Code Provider County Name            Ownership Type  \
# 0              36025               Elmore  For profit - Corporation
# 1              35601               Morgan  For profit - Corporation
# ...

# %%
df_clean.head()
# Out:
#                                      Provider Name  \
# 0  MERRY WOOD LODGE CARE AND REHABILITATION CENTER
# 1                                RIVER CITY CENTER
# 2  MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER
# 3                   SHADESCREST HEALTH CARE CENTER
# 4                   WASHINGTON COUNTY NURSING HOME
#
#                    Provider Address Provider City Provider State  \
# 0                       P O BOX 130        ELMORE             AL
# 1  1350 FOURTEENTH AVENUE SOUTHEAST       DECATUR             AL
# 2                 603 WRIGHT STREET      TUSKEGEE             AL
# 3              331 WEST 25TH STREET        JASPER             AL
# 4          14600 ST STEPHENS AVENUE        CHATOM             AL
#
#    Provider Zip Code Provider County Name            Ownership Type  \
# 0              36025               Elmore  For profit - Corporation
# 1              35601               Morgan  For profit - Corporation
# ...

# %%
df_clean.to_csv("provider_info_cleaned.csv", index=False)

# %%
files.download("provider_info_cleaned.csv")

# %%
df["Ownership Type"].unique()
# Out:
# array(['For profit - Corporation', 'Government - County',
#        'For profit - Partnership', 'Non profit - Corporation',
#        'For profit - Individual', 'Government - City',
#        'Government - State', 'Non profit - Church related',
#        'Government - Hospital district', 'Government - City/county',
#        'For profit - Limited Liability company', 'Non profit - Other',
#        'Government - Federal'], dtype=object)

# %%
df["Overall Rating"].unique()
# Out:
# array([ 4.,  1.,  5.,  2.,  3., nan])

# %%
df[["Provider Name", "Provider State", "Ownership Type", "Overall Rating", "Location"]].head()
# Out:
#                                      Provider Name Provider State  \
# 0  MERRY WOOD LODGE CARE AND REHABILITATION CENTER             AL
# 1                                RIVER CITY CENTER             AL
# 2  MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER             AL
# 3                   SHADESCREST HEALTH CARE CENTER             AL
# 4                   WASHINGTON COUNTY NURSING HOME             AL
#
#              Ownership Type  Overall Rating  \
# 0  For profit - Corporation             4.0
# 1  For profit - Corporation             1.0
# 2  For profit - Corporation             5.0
# 3  For profit - Corporation             4.0
# 4       Government - County             4.0
#
#                                             Location
# 0                             130 ELMORE\nAL 36025\n
# 1  1350 FOURTEENTH AVENUE SOUTHEAST\nDECATUR, AL ...
# 2  603 WRIGHT STREET\nTUSKEGEE, AL 36083\n(32.432...
# 3  331 WEST 25TH STREET\nJASPER, AL 35502\n(33.82...
# ...
